# %%
#!/usr/bin/python
import json,os
from functools import reduce

data_fn_simp = os.path.join('idiom_simp.json')
with open(data_fn_simp) as fo:
    idiom_data = json.loads(fo.read())

test = True

# %%
def filter_shengdiao(data,include='0000',exclude='0000',show=False):
# input para:
#     data: idiom data
#     include: the right shengdiao at this position
#     exclude: shengdiao included in the idiom but not at this position
# caution: shengdiao neither in 'include' nor in 'exclude' is considered to be not in the idiom, so use a idiom with all four shengdiaos in your first try.
    count = 0
    for chengyu in data:
        sd = chengyu['shengdiao']
        # check char number, must be 4
        if len(sd) != 4:
            continue
        # check shengdiao of each char
        flag = True
        for i in range(4):
            isd = sd[i]
            if include[i] != '0' and isd != include[i]:
                flag = False
                break
            if isd == exclude[i]:
                flag = False
                break
            if not isd in include+exclude:
                flag = False
                break
            iex = exclude[i]
            if iex != '0' and iex not in sd:
                flag = False
                break
        if not flag: continue
        count += 1
        if show and count<1000: print('%03d'%count,chengyu['word'],'%6s%6s%6s%6s'%tuple(chengyu['pinyin']))
        yield chengyu
# test
if test:
    result1 = list(filter_shengdiao(idiom_data,include='0004',exclude='3120',show=True))
    result2 = list(filter_shengdiao(result1,include='1234',show=True))
# Out:
# 001 阿其所好      ē    qí   suǒ   hào
# 002 阿谀谄媚      ē    yú  chǎn   mèi
# 003 安常处顺     ān cháng   chǔ  shùn
# 004 安常履顺     ān cháng    lǚ  shùn
# 005 安常守分     ān cháng  shǒu   fèn
# 006 安常守故     ān cháng  shǒu    gù
# 007 安贫守道     ān   pín  shǒu   dào
# 008 安时处顺     ān   shí   chǔ  shùn
# 009 鞍前马后     ān  qián    mǎ   hòu
# 010 昂首天外    áng  shǒu  tiān   wài
# 011 白眼相看    bái   yǎn xiāng   kàn
# 012 白纸黑字    bái   zhǐ   hēi    zì
# 013 邦国殄瘁   bāng   guó  tiǎn   cuì
# 014 膘肥体壮   biāo   féi    tǐzhuàng
# 015 别有风趣    bié   yǒu  fēng    qù
# 016 别有风味    bié   yǒu  fēng   wèi
# 017 别有天地    bié   yǒu  tiān    dì
# 018 别有滋味    bié   yǒu    zī   wèi
# 019 宾朋满座    bīn  péng   mǎn   zuò
# 020 冰魂雪魄   bīng   hún   xuě    pò
# 021 兵强马壮   bīng qiáng    mǎzhuàng
# 022 兵行诡道   bīng  xíng   guǐ   dào
# 023 拨云睹日     bō   yún    dǔ    rì
# 024 才短思涩    cái  duǎn    sī    sè
# 025 餐霞饮瀣    cān   xiá   yǐn   xiè
# 026 餐霞饮液    cān   xiá   yǐn    yè
# 027 苍黄反复   cāng huáng   fǎn    fù
# 028 长久之计  cháng   jiǔ   zhī    jì
# 029 倡条冶叶  chāng  tiáo    yě    yè
# 030 车尘马迹    chē  zhén    mǎ    jì
# 031 车驰马骤    chē   chí    mǎ  zhòu
# 032 车烦马毙    chē   fán    mǎ    bì
# 033 车填马隘    chē  tián    mǎ    ài
# 034 车辙马迹    chē   zhé    mǎ    jì
# 035 撑肠拄肚  chēng cháng   zhǔ    dù
# 036 撑肠拄腹  chēng cháng   zhǔ    fù
# 037 持久之计    chí   jiǔ   zhī    jì
# 038 出词吐气    chū    cí    tǔ    qì
# 039 出何典记    chū    hé  diǎn    jì
# 040 出奇取胜    chū    qí    qǔ shèng
# 041 出言吐气    chū   yán    tǔ    qì
# 042 疮痍满目 chuāng    yí   mǎn    mù
# 043 吹毛索垢   chuī   máo   suǒ   gòu
# 044 吹毛洗垢   chuī   máo    xǐ   gòu
# 045 撺拳拢袖   cuān  quán  lǒng   xiù
# 046 当门抵户   dāng   mén    dǐ    hù
# 047 当行本色   dāng  xíng   běn    sè
# 048 刀头舔蜜    dāo   tóu  tiǎn    mì
# 049 灯红酒绿   dēng  hóng   jiǔ    lǜ
# 050 低吟浅唱     dī   yín  qiǎn chàng
# 051 颠来簸去   diān   lái    bǒ    qù
# 052 颠来倒去   diān   lái   dǎo    qù
# 053 颠鸾倒凤   diān  luán   dǎo  fèng
# 054 彫虫小技   diāo chóng  xiǎo    jì
# 055 貂蝉满座   diāo  chán   mǎn   zuò
# 056 雕虫小技   diāo chóng  xiǎo    jì
# 057 雕虫小事   diāo chóng  xiǎo   shì
# 058 雕虫小艺   diāo chóng  xiǎo    yì
# 059 东床坦腹   dōngchuáng   tǎn    fù
# 060 掇臀捧屁    duō   tún  pěng    pì
# 061 额手称庆      é  shǒu chēng  qìng
# 062 额手称颂      é  shǒu chēng  sòng
# 063 额手相庆      é  shǒu xiāng  qìng
# 064 发凡起例     fā   fán    qǐ    lì
# 065 发蒙解惑     fā  méng   jiě   huò
# 066 发扬蹈厉     fā  yáng   dǎo    lì
# 067 幡然悔悟    fān   rán   huǐ    wù
# 068 翻肠搅肚    fān cháng  jiǎo    dù
# 069 翻黄倒皂    fān huáng   dǎo   zào
# 070 翻然改进    fān   rán   gǎi   jìn
# 071 翻然悔悟    fān   rán   huǐ    wù
# 072 飞刍挽粒    fēi   chú   wǎn    lì
# 073 飞刍挽粟    fēi   chú   wǎn    sù
# 074 飞粮挽秣    fēi liáng   wǎn    mò
# 075 飞禽走兽    fēi   qín   zǒu  shòu
# 076 飞文染翰    fēi   wén   rǎn   hàn
# 077 飞沿走壁    fēi   yán   zǒu    bì
# 078 飞檐走壁    fēi   yán   zǒu    bì
# 079 分朋引类    fēn  péng   yǐn   lèi
# 080 丰年稔岁   fēng  nián   rěn   suì
# 081 风驰雨骤   fēng   chí    yǔ  zhòu
# 082 风调雨顺   fēng  tiáo    yǔ  shùn
# 083 风鬟雨鬓   fēng  huán    yǔ   bìn
# 084 风雷火炮   fēng   léi   huǒ   pào
# 085 风行水上   fēng  xíng  shuǐ shàng
# 086 风行雨散   fēng  xíng    yǔ   sàn
# 087 风烛草露   fēng   zhú   cǎo    lù
# 088 锋芒所向   fēng  máng   suǒ xiàng
# 089 蜂合蚁聚   fēng    hé    yǐ    jù
# 090 蜂屯蚁附   fēng   tún    yǐ    fù
# 091 蜂屯蚁聚   fēng   tún    yǐ    jù
# 092 蜂营蚁队   fēng  yíng    yǐ   duì
# 093 蜂攒蚁聚   fēng  cuán    yǐ    jù
# 094 逢场竿木   féng chǎng   gān    mù
# 095 佛眼相看     fó   yǎn xiāng   kàn
# 096 桴鼓相应     fú    gǔ xiāng  yìng
# 097 干名采誉    gān  míng   cǎi    yù
# 098 纲提领挈   gāng    tí  lǐng   qiè
# 099 高朋满座    gāo  péng   mǎn   zuò
# 100 高情远意    gāo  qíng  yuǎn    yì
# 101 高情远韵    gāo  qíng  yuǎn   yùn
# 102 高情远致    gāo  qíng  yuǎn   zhì
# 103 高人雅士    gāo   rén    yǎ   shì
# 104 高识远见    gāo   shí  yuǎn  jiàn
# 105 高文典册    gāo   wén  diǎn    cè
# 106 高文典策    gāo   wén  diǎn    cè
# 107 膏梁锦绣    gāo liáng   jǐn   xiù
# 108 膏梁子弟    gāo liáng    zǐ    dì
# 109 膏粱锦绣    gāo liáng   jǐn   xiù
# 110 膏粱子弟    gāo liáng    zǐ    dì
# 111 膏腴子弟    gāo    yú    zǐ    dì
# 112 歌楼舞榭     gē   lóu    wǔ   xiè
# 113 歌台舞榭     gē   tái    wǔ   xiè
# 114 歌莺舞燕     gē  yíng    wǔ   yàn
# 115 攻城掠地   gōng chéng   lüě    dì
# 116 攻城野战   gōng chéng    yě  zhàn
# 117 攻瑕索垢   gōng   xiá   suǒ   gòu
# 118 孤雌寡鹤     gū    cí   guǎ    hè
# 119 孤儿寡妇     gū    ér   guǎ    fù
# 120 孤行己见     gū  xíng    jǐ  jiàn
# 121 孤行己意     gū  xíng    jǐ    yì
# 122 孤云野鹤     gū   yún    yě    hè
# 123 瓜田李下    guā  tián    lǐ   xià
# 124 刮肠洗胃    guā cháng    xǐ   wèi
# 125 鳏鱼渴凤   guān    yú    kě  fèng
# 126 光明磊落  guāng  míng   lěi   luò
# 127 光前启后  guāng  qián    qǐ   hòu
# 128 归邪转曜    guī   xié zhuǎn   yào
# 129 龟文鸟迹    guī   wén  niǎo    jì
# 130 规绳矩墨    guī shéng    jǔ    mò
# 131 规贤矩圣    guī  xián    jǔ shèng
# 132 规行矩步    guī  xíng    jǔ    bù
# 133 规言矩步    guī   yán    jǔ    bù
# 134 合眼摸象     hé   yǎn    mō xiàng
# 135 河海清宴     hé   hǎi  qīng   yàn
# 136 呼朋引类     hū  péng   yǐn   lèi
# 137 瑚琏之器     hú  liǎn   zhī    qì
# 138 花红柳绿    huā  hóng   liǔ    lǜ
# 139 花明柳暗    huā  míng   liǔ    àn
# 140 花明柳媚    huā  míng   liǔ   mèi
# 141 花衢柳陌    huā    qú   liǔ    mò
# 142 花团锦簇    huā  tuán   jǐn    cù
# 143 花攒锦簇    huā  cuán   jǐn    cù
# 144 花攒锦聚    huā  cuán   jǐn    jù
# 145 灰容土貌    huī  róng    tǔ   mào
# 146 灰头土面    huī   tóu    tǔ  miàn
# 147 昏头转向    hūn   tóu zhuǎn xiàng
# 148 击搏挽裂     jī    bó   wǎn   liè
# 149 鸡肠狗肚     jī cháng   gǒu    dù
# 150 鸡零狗碎     jī  líng   gǒu   suì
# 151 鸡鸣狗盗     jī  míng   gǒu   dào
# 152 鸡鸣狗吠     jī  míng   gǒu   fèi
# 153 鸡鸣犬吠     jī  míng  quǎn   fèi
# 154 积德累善     jī    dé   lěi  shàn
# 155 积年累岁     jī  nián   lěi   suì
# 156 积年累月     jī  nián   lěi   yuè
# 157 积时累日     jī   shí   lěi    rì
# 158 奸淫掳掠   jiān   yín    lǔ   lüè
# 159 肩从齿序   jiān  cóng   chǐ    xù
# 160 郊寒岛瘦   jiāo   hán   dǎo  shòu
# 161 今愁古恨    jīn  chóu    gǔ   hèn
# 162 金迷纸碎    jīn    mí   zhǐ   suì
# 163 金迷纸醉    jīn    mí   zhǐ   zuì
# 164 矜才使气    jīn   cái   shǐ    qì
# 165 襟怀磊落    jīn  huái   lěi   luò
# 166 襟怀洒落    jīn  huái    sǎ   luò
# 167 经纶满腹   jīng   lún   mǎn    fù
# 168 经年累月   jīng  nián   lěi   yuè
# 169 精诚所至   jīng chéng   suǒ   zhì
# 170 精神百倍   jīng  shén   bǎi   bèi
# 171 精神满腹   jīng  shén   mǎn    fù
# 172 拘挛补衲     jū  luán    bǔ    nà
# 173 拘神遣将     jū  shén  qiǎn jiàng
# 174 磕头礼拜     kē   tóu    lǐ   bài
# 175 坑蒙拐骗   kēng  méng  guǎi  piàn
# 176 宽洪海量   kuān  hóng   hǎi liàng
# 177 来者居上    lái   zhě    jū shàng
# 178 兰芷之室    lán   zhǐ   zhī   shì
# 179 离本徼末     lí   běn   yāo    mò
# 180 离本趣末     lí   běn    qū    mò
# 181 离本依末     lí   běn    yī    mò
# 182 连理之木   lián    lǐ   zhī    mù
# 183 门闾之望    mén    lǚ   zhī  wàng
# 184 名满天下   míng   mǎn  tiān   xià
# 185 牛口之下    niú   kǒu   zhī   xià
# 186 喷云吐雾    pēn   yún    tǔ    wù
# 187 烹龙煮凤   pēng  lóng   zhǔ  fèng
# 188 批鳞请剑     pī   lín  qǐng  jiàn
# 189 皮里抽肉     pí    lǐ  chōu   ròu
# 190 凭几之诏   píng    jǐ   zhī  zhào
# 191 蒲柳之质     pú   liǔ   zhī   zhì
# 192 妻离子散     qī    lí    zǐ   sàn
# 193 妻梅子鹤     qī   mén    zǐ    hè
# 194 千锤百炼   qiān  chuí   bǎi  liàn
# 195 千伶百俐   qiān  líng   bǎi    lì
# 196 千奇百怪   qiān    qí   bǎi  guài
# 197 千随百顺   qiān   suí   bǎi  shùn
# 198 搴旗取将   qiān    qí    qǔ jiàng
# 199 搴旗斩将   qiān    qí  zhǎn jiàng
# 200 强弩之末  qiáng    nǔ   zhī    mò
# 201 亲如骨肉    qīn    rú    gǔ   ròu
# 202 亲贤远佞    qīn  xián  yuǎn  nìng
# 203 嵚崎磊落    qīn    qí   lěi   luò
# 204 青裙缟袂   qīng   qún   gǎo   mèi
# 205 青堂瓦舍   qīng  táng    wǎ   shè
# 206 青蝇点璧   qīng  yíng  diǎn    bì
# 207 青蝇点素   qīng  yíng  diǎn    sù
# 208 青蝇点玉   qīng  yíng  diǎn    yù
# 209 轻财好士   qīng   cái   hǎo   shì
# 210 轻裘缓带   qīng   qiú  huǎn   dài
# 211 轻裘缓辔   qīng   qiú  huǎn   pèi
# 212 轻言寡信   qīng   yán   guǎ   xìn
# 213 裘马声色    qiú    mǎ shēng    sè
# 214 屈节辱命     qū   jié    rǔ  mìng
# 215 饶有风趣    ráo   yǒu  fēng    qù
# 216 人己一视    rén    jǐ    yī   shì
# 217 人手一册    rén  shǒu    yī    cè
# 218 戎马劻勷   róng    mǎ   dān  xiào
# 219 如虎生翼     rú    hǔ shēng    yì
# 220 如虎添翼     rú    hǔ  tiān    yì
# 221 三朝五日    sān  cháo    wǔ    rì
# 222 三环五扣    sān  huán    wǔ   kòu
# 223 三皇五帝    sān huáng    wǔ    dì
# 224 三回五次    sān   huí    wǔ    cì
# 225 三节两寿    sān   jié liǎng  shòu
# 226 三年五载    sān  nián    wǔ   zài
# 227 三头两面    sān   tóu liǎng  miàn
# 228 三头两日    sān   tóu liǎng    rì
# 229 三头两绪    sān   tóu liǎng    xù
# 230 三言两句    sān   yán liǎng    jù
# 231 三足鼎立    sān    zú  dǐng    lì
# 232 骚人雅士    sāo   rén    yǎ   shì
# 233 山长水阔   shān cháng  shuǐ   kuò
# 234 山节藻棁   shān   jié   zǎo    lì
# 235 山林隐逸   shān   lín   yǐn    yì
# 236 山盟海誓   shān  méng   hǎi   shì
# 237 山明水秀   shān  míng  shuǐ   xiù
# 238 山鸣谷应   shān  míng    gǔ  yìng
# 239 山穷水断   shān qióng  shuǐ  duàn
# 240 山穷水尽   shān qióng  shuǐ   jìn
# 241 山容海纳   shān  róng   hǎi    nà
# 242 山肴海错   shān   yáo   hǎi   cuò
# 243 山肴野蔌   shān   yáo    yě    sù
# 244 烧琴煮鹤   shāo   qín   zhǔ    hè
# 245 深仇宿怨   shēn  chóu   xiǔ  yuàn
# 246 深谋远虑   shēn   móu  yuǎn    lǜ
# 247 深谋远略   shēn   móu  yuǎn   lüè
# 248 深图远算   shēn    tú  yuǎn  suàn
# 249 深猷远计   shēn   yóu  yuǎn    jì
# 250 神竦心惕   shén  sǒng   xīn    tì
# 251 生财有道  shēng   cái   yǒu   dào
# 252 诗肠鼓吹    shī   chá    gǔ  chuì
# 253 诗云子曰    shī   yún    zǐ   yuè
# 254 殊形诡状    shū  xíng   guǐzhuàng
# 255 梳云掠月    shū   yún   lüě   yuè
# 256 思前想后     sī  qián xiǎng   hòu
# 257 斯文扫地     sī   wén   sǎo    dì
# 258 搜岩采干    sōu   yán   cǎi   gàn
# 259 酸甜苦辣   suān  tián    kǔ    là
# 260 酸文假醋   suān   wén   jiǎ    cù
# 261 酸咸苦辣   suān  xián    kǔ    là
# 262 桃李之教    táo    lǐ   zhī  jiào
# 263 桃李之馈    táo    lǐ   zhī   kuì
# 264 挑肥拣瘦   tiāo   féi  jiǎn  shòu
# 265 挑毛拣刺   tiāo   máo  jiǎn    cì
# 266 通衢广陌   tōng    qú guǎng    mò
# 267 同美相妒   tóng   měi xiāng    dù
# 268 偷闲躲静    tōu  xián   duǒ  jìng
# 269 投鼠之忌    tóu   shǔ   zhī    jì
# 270 吞云吐雾    tūn   yún    tǔ    wù
# 271 危言竦论    wēi   yán  sǒng   lùn
# 272 偎红倚翠    wēi  hóng    yǐ   cuì
# 273 文武兼备    wén    wǔ  jiān   bèi
# 274 文武之道    wén    wǔ   zhī   dào
# 275 无可非议     wú    kě   fēi    yì
# 276 无可争辩     wú    kě zhēng  biàn
# 277 梧鼠之技     wú   shǔ   zhī    jì
# 278 希奇古怪     xī    qí    gǔ  guài
# 279 析骸以爨     xī   hái    yǐ  cuàn
# 280 息黥补劓     xī  qíng    bǔ    yì
# 281 稀奇古怪     xī    qí    gǔ  guài
# 282 膝行肘步     xī  xíng  zhǒu    bù
# 283 席卷天下     xí  juǎn  tiān   xià
# 284 席履丰厚     xí    lǚ  fēng   hòu
# 285 掀拳裸袖   xiān  quán   luǒ   xiù
# 286 相濡以沫  xiāng    rú    yǐ    mò
# 287 枭蛇鬼怪   xiāo   shé   guǐ  guài
# 288 消愁解闷   xiāo  chóu   jiě   mèn
# 289 逍遥法外   xiāo   yáo    fǎ   wài
# 290 鸮鸣鼠暴  zhāng  míng   shǔ   bào
# 291 心寒胆落    xīn   hán   dǎn   luò
# 292 心寒胆战    xīn   hán   dǎn  zhàn
# 293 心怀叵测    xīn  huái    pǒ    cè
# 294 心怀忐忑    xīn  huái   tǎn    tè
# 295 心明眼亮    xīn  míng   yǎn liàng
# 296 心如槁木    xīn    rú   gǎo    mù
# 297 心直口快    xīn   zhí   kǒu  kuài
# 298 心直嘴快    xīn   zhí   zuǐ  kuài
# 299 星离雨散   xīng    lí    yǔ   sàn
# 300 形影相吊   xíng  yǐng xiāng  diào
# 301 形影相对   xíng  yǐng xiāng   duì
# 302 形影相附   xíng  yǐng xiāng    fù
# 303 胸怀磊落  xiōng  huái   lěi   luò
# 304 胸无点墨  xiōng    wú  diǎn    mò
# 305 修桥补路    xiū  qiáo    bǔ    lù
# 306 虚情假意     xū  qíng   jiǎ    yì
# 307 揎拳拢袖   xuān  quán  lǒng   xiù
# 308 揎拳掳袖   xuān  quán    lǔ   xiù
# 309 揎拳裸臂   xuān  quán   luǒ    bì
# 310 揎拳裸袖   xuān  quán   luǒ   xiù
# 311 揎拳捰袖   xuān  quán  lǒng   xiù
# 312 揎拳舞袖   xuān  quán    wǔ   xiù
# 313 玄圃积玉   xuán    pǔ    jī    yù
# 314 妖魔鬼怪    yāo    mó   guǐ  guài
# 315 一劳久逸     yī   láo   jiǔ    yì
# 316 一劳永逸     yī   láo  yǒng    yì
# 317 一硼地     yī   niú   hǒu    dì
# 318 一人有庆     yī   rén   yǒu  qìng
# 319 一无所获     yī    wú   suǒ   huò
# 320 依头缕当     yī   tóu    lǚ  dàng
# 321 因循守旧    yīn   xún  shǒu   jiù
# 322 阴谋诡计    yīn   móu   guǐ    jì
# 323 音容宛在    yīn  róng   wǎn   zài
# 324 英雄本色   yīng xióng   běn    sè
# 325 鹰瞵虎视   yīng   lín    hǔ   shì
# 326 鹰扬虎视   yīng  yáng    hǔ   shì
# 327 鹰扬虎噬   yīng  yáng    hǔ   shì
# 328 盈满之咎   yíng   mǎn   zhī   jiù
# 329 雍荣雅步   yōng  róng    yǎ    bù
# 330 雍容雅步   yōng  róng    yǎ    bù
# 331 优柔寡断    yōu   róu   guǎ  duàn
# 332 鱼米之地     yú    mǐ   zhī    dì
# 333 渊谋远略   yuān   móu  yuǎn   lüè
# 334 渊图远算   yuān    tú  yuǎn  suàn
# 335 渊源有自   yuān  yuán   yǒu    zì
# 336 圆孔方木   yuán  kǒng  fāng    mù
# 337 张眉努目  zhāng   méi    nǔ    mù
# 338 张王李赵  zhāng  wáng    lǐ  zhào
# 339 獐头鼠目  zhāng   tóu   shǔ    mù
# 340 遮前掩后    zhē  qián   yǎn   hòu
# 341 遮人耳目    zhē   rén    ěr    mù
# 342 遮人眼目    zhē   rén   yǎn    mù
# 343 真独简贵   zhēn    dú  jiǎn   guì
# 344 争前恐后  zhēng  qián  kǒng   hòu
# 345 争强显胜  zhēng qiáng  xiǎn shèng
# 346 争权攘利  zhēng  quán  rǎng    lì
# 347 中流底柱  zhōng   liú    dǐ   zhù
# 348 中流砥柱  zhōng   liú    dǐ   zhù
# 349 钟鸣鼎列  zhōng  míng  dǐng   liè
# 350 钟鸣鼎重  zhōng  míng  dǐng zhòng
# 351 重睹天日  chóng    dǔ  tiān    rì
# 352 朱唇粉面    zhū  chún   fěn  miàn
# 353 朱楼绮户    zhū   lóu    qǐ    hù
# 354 珠零锦粲    zhū  líng   jǐn   càn
# 355 诸如此类    zhū    rú    cǐ   lèi
# 356 诸如此例    zhū    rú    cǐ    lì
# 357 庄严宝相 zhuāng   yán   bǎo xiàng
# 358 遵时养晦    zūn   shí  yǎng   huì
# 001 阿其所好      ē    qí   suǒ   hào
# 002 阿谀谄媚      ē    yú  chǎn   mèi
# 003 安常处顺     ān cháng   chǔ  shùn
# 004 安常履顺     ān cháng    lǚ  shùn
# 005 安常守分     ān cháng  shǒu   fèn
# 006 安常守故     ān cháng  shǒu    gù
# 007 安贫守道     ān   pín  shǒu   dào
# 008 安时处顺     ān   shí   chǔ  shùn
# 009 鞍前马后     ān  qián    mǎ   hòu
# 010 邦国殄瘁   bāng   guó  tiǎn   cuì
# 011 膘肥体壮   biāo   féi    tǐzhuàng
# 012 宾朋满座    bīn  péng   mǎn   zuò
# 013 冰魂雪魄   bīng   hún   xuě    pò
# 014 兵强马壮   bīng qiáng    mǎzhuàng
# 015 兵行诡道   bīng  xíng   guǐ   dào
# 016 拨云睹日     bō   yún    dǔ    rì
# 017 餐霞饮瀣    cān   xiá   yǐn   xiè
# 018 餐霞饮液    cān   xiá   yǐn    yè
# 019 苍黄反复   cāng huáng   fǎn    fù
# 020 倡条冶叶  chāng  tiáo    yě    yè
# 021 车尘马迹    chē  zhén    mǎ    jì
# 022 车驰马骤    chē   chí    mǎ  zhòu
# 023 车烦马毙    chē   fán    mǎ    bì
# 024 车填马隘    chē  tián    mǎ    ài
# 025 车辙马迹    chē   zhé    mǎ    jì
# 026 撑肠拄肚  chēng cháng   zhǔ    dù
# 027 撑肠拄腹  chēng cháng   zhǔ    fù
# 028 出词吐气    chū    cí    tǔ    qì
# 029 出何典记    chū    hé  diǎn    jì
# 030 出奇取胜    chū    qí    qǔ shèng
# 031 出言吐气    chū   yán    tǔ    qì
# 032 疮痍满目 chuāng    yí   mǎn    mù
# 033 吹毛索垢   chuī   máo   suǒ   gòu
# 034 吹毛洗垢   chuī   máo    xǐ   gòu
# 035 撺拳拢袖   cuān  quán  lǒng   xiù
# 036 当门抵户   dāng   mén    dǐ    hù
# 037 当行本色   dāng  xíng   běn    sè
# 038 刀头舔蜜    dāo   tóu  tiǎn    mì
# 039 灯红酒绿   dēng  hóng   jiǔ    lǜ
# 040 低吟浅唱     dī   yín  qiǎn chàng
# 041 颠来簸去   diān   lái    bǒ    qù
# 042 颠来倒去   diān   lái   dǎo    qù
# 043 颠鸾倒凤   diān  luán   dǎo  fèng
# 044 彫虫小技   diāo chóng  xiǎo    jì
# 045 貂蝉满座   diāo  chán   mǎn   zuò
# 046 雕虫小技   diāo chóng  xiǎo    jì
# 047 雕虫小事   diāo chóng  xiǎo   shì
# 048 雕虫小艺   diāo chóng  xiǎo    yì
# 049 东床坦腹   dōngchuáng   tǎn    fù
# 050 掇臀捧屁    duō   tún  pěng    pì
# 051 发凡起例     fā   fán    qǐ    lì
# 052 发蒙解惑     fā  méng   jiě   huò
# 053 发扬蹈厉     fā  yáng   dǎo    lì
# 054 幡然悔悟    fān   rán   huǐ    wù
# 055 翻肠搅肚    fān cháng  jiǎo    dù
# 056 翻黄倒皂    fān huáng   dǎo   zào
# 057 翻然改进    fān   rán   gǎi   jìn
# 058 翻然悔悟    fān   rán   huǐ    wù
# 059 飞刍挽粒    fēi   chú   wǎn    lì
# 060 飞刍挽粟    fēi   chú   wǎn    sù
# 061 飞粮挽秣    fēi liáng   wǎn    mò
# 062 飞禽走兽    fēi   qín   zǒu  shòu
# 063 飞文染翰    fēi   wén   rǎn   hàn
# 064 飞沿走壁    fēi   yán   zǒu    bì
# 065 飞檐走壁    fēi   yán   zǒu    bì
# 066 分朋引类    fēn  péng   yǐn   lèi
# 067 丰年稔岁   fēng  nián   rěn   suì
# 068 风驰雨骤   fēng   chí    yǔ  zhòu
# 069 风调雨顺   fēng  tiáo    yǔ  shùn
# 070 风鬟雨鬓   fēng  huán    yǔ   bìn
# 071 风雷火炮   fēng   léi   huǒ   pào
# 072 风行水上   fēng  xíng  shuǐ shàng
# 073 风行雨散   fēng  xíng    yǔ   sàn
# 074 风烛草露   fēng   zhú   cǎo    lù
# 075 锋芒所向   fēng  máng   suǒ xiàng
# 076 蜂合蚁聚   fēng    hé    yǐ    jù
# 077 蜂屯蚁附   fēng   tún    yǐ    fù
# 078 蜂屯蚁聚   fēng   tún    yǐ    jù
# 079 蜂营蚁队   fēng  yíng    yǐ   duì
# 080 蜂攒蚁聚   fēng  cuán    yǐ    jù
# 081 干名采誉    gān  míng   cǎi    yù
# 082 纲提领挈   gāng    tí  lǐng   qiè
# 083 高朋满座    gāo  péng   mǎn   zuò
# 084 高情远意    gāo  qíng  yuǎn    yì
# 085 高情远韵    gāo  qíng  yuǎn   yùn
# 086 高情远致    gāo  qíng  yuǎn   zhì
# 087 高人雅士    gāo   rén    yǎ   shì
# 088 高识远见    gāo   shí  yuǎn  jiàn
# 089 高文典册    gāo   wén  diǎn    cè
# 090 高文典策    gāo   wén  diǎn    cè
# 091 膏梁锦绣    gāo liáng   jǐn   xiù
# 092 膏梁子弟    gāo liáng    zǐ    dì
# 093 膏粱锦绣    gāo liáng   jǐn   xiù
# 094 膏粱子弟    gāo liáng    zǐ    dì
# 095 膏腴子弟    gāo    yú    zǐ    dì
# 096 歌楼舞榭     gē   lóu    wǔ   xiè
# 097 歌台舞榭     gē   tái    wǔ   xiè
# 098 歌莺舞燕     gē  yíng    wǔ   yàn
# 099 攻城掠地   gōng chéng   lüě    dì
# 100 攻城野战   gōng chéng    yě  zhàn
# 101 攻瑕索垢   gōng   xiá   suǒ   gòu
# 102 孤雌寡鹤     gū    cí   guǎ    hè
# 103 孤儿寡妇     gū    ér   guǎ    fù
# 104 孤行己见     gū  xíng    jǐ  jiàn
# 105 孤行己意     gū  xíng    jǐ    yì
# 106 孤云野鹤     gū   yún    yě    hè
# 107 瓜田李下    guā  tián    lǐ   xià
# 108 刮肠洗胃    guā cháng    xǐ   wèi
# 109 鳏鱼渴凤   guān    yú    kě  fèng
# 110 光明磊落  guāng  míng   lěi   luò
# 111 光前启后  guāng  qián    qǐ   hòu
# 112 归邪转曜    guī   xié zhuǎn   yào
# 113 龟文鸟迹    guī   wén  niǎo    jì
# 114 规绳矩墨    guī shéng    jǔ    mò
# 115 规贤矩圣    guī  xián    jǔ shèng
# 116 规行矩步    guī  xíng    jǔ    bù
# 117 规言矩步    guī   yán    jǔ    bù
# 118 呼朋引类     hū  péng   yǐn   lèi
# 119 花红柳绿    huā  hóng   liǔ    lǜ
# 120 花明柳暗    huā  míng   liǔ    àn
# 121 花明柳媚    huā  míng   liǔ   mèi
# 122 花衢柳陌    huā    qú   liǔ    mò
# 123 花团锦簇    huā  tuán   jǐn    cù
# 124 花攒锦簇    huā  cuán   jǐn    cù
# 125 花攒锦聚    huā  cuán   jǐn    jù
# 126 灰容土貌    huī  róng    tǔ   mào
# 127 灰头土面    huī   tóu    tǔ  miàn
# 128 昏头转向    hūn   tóu zhuǎn xiàng
# 129 击搏挽裂     jī    bó   wǎn   liè
# 130 鸡肠狗肚     jī cháng   gǒu    dù
# 131 鸡零狗碎     jī  líng   gǒu   suì
# 132 鸡鸣狗盗     jī  míng   gǒu   dào
# 133 鸡鸣狗吠     jī  míng   gǒu   fèi
# 134 鸡鸣犬吠     jī  míng  quǎn   fèi
# 135 积德累善     jī    dé   lěi  shàn
# 136 积年累岁     jī  nián   lěi   suì
# 137 积年累月     jī  nián   lěi   yuè
# 138 积时累日     jī   shí   lěi    rì
# 139 奸淫掳掠   jiān   yín    lǔ   lüè
# 140 肩从齿序   jiān  cóng   chǐ    xù
# 141 郊寒岛瘦   jiāo   hán   dǎo  shòu
# 142 今愁古恨    jīn  chóu    gǔ   hèn
# 143 金迷纸碎    jīn    mí   zhǐ   suì
# 144 金迷纸醉    jīn    mí   zhǐ   zuì
# 145 矜才使气    jīn   cái   shǐ    qì
# 146 襟怀磊落    jīn  huái   lěi   luò
# 147 襟怀洒落    jīn  huái    sǎ   luò
# 148 经纶满腹   jīng   lún   mǎn    fù
# 149 经年累月   jīng  nián   lěi   yuè
# 150 精诚所至   jīng chéng   suǒ   zhì
# 151 精神百倍   jīng  shén   bǎi   bèi
# 152 精神满腹   jīng  shén   mǎn    fù
# 153 拘挛补衲     jū  luán    bǔ    nà
# 154 拘神遣将     jū  shén  qiǎn jiàng
# 155 磕头礼拜     kē   tóu    lǐ   bài
# 156 坑蒙拐骗   kēng  méng  guǎi  piàn
# 157 宽洪海量   kuān  hóng   hǎi liàng
# 158 喷云吐雾    pēn   yún    tǔ    wù
# 159 烹龙煮凤   pēng  lóng   zhǔ  fèng
# 160 批鳞请剑     pī   lín  qǐng  jiàn
# 161 妻离子散     qī    lí    zǐ   sàn
# 162 妻梅子鹤     qī   mén    zǐ    hè
# 163 千锤百炼   qiān  chuí   bǎi  liàn
# 164 千伶百俐   qiān  líng   bǎi    lì
# 165 千奇百怪   qiān    qí   bǎi  guài
# 166 千随百顺   qiān   suí   bǎi  shùn
# 167 搴旗取将   qiān    qí    qǔ jiàng
# 168 搴旗斩将   qiān    qí  zhǎn jiàng
# 169 亲如骨肉    qīn    rú    gǔ   ròu
# 170 亲贤远佞    qīn  xián  yuǎn  nìng
# 171 嵚崎磊落    qīn    qí   lěi   luò
# 172 青裙缟袂   qīng   qún   gǎo   mèi
# 173 青堂瓦舍   qīng  táng    wǎ   shè
# 174 青蝇点璧   qīng  yíng  diǎn    bì
# 175 青蝇点素   qīng  yíng  diǎn    sù
# 176 青蝇点玉   qīng  yíng  diǎn    yù
# 177 轻财好士   qīng   cái   hǎo   shì
# 178 轻裘缓带   qīng   qiú  huǎn   dài
# 179 轻裘缓辔   qīng   qiú  huǎn   pèi
# 180 轻言寡信   qīng   yán   guǎ   xìn
# 181 屈节辱命     qū   jié    rǔ  mìng
# 182 三朝五日    sān  cháo    wǔ    rì
# 183 三环五扣    sān  huán    wǔ   kòu
# 184 三皇五帝    sān huáng    wǔ    dì
# 185 三回五次    sān   huí    wǔ    cì
# 186 三节两寿    sān   jié liǎng  shòu
# 187 三年五载    sān  nián    wǔ   zài
# 188 三头两面    sān   tóu liǎng  miàn
# 189 三头两日    sān   tóu liǎng    rì
# 190 三头两绪    sān   tóu liǎng    xù
# 191 三言两句    sān   yán liǎng    jù
# 192 三足鼎立    sān    zú  dǐng    lì
# 193 骚人雅士    sāo   rén    yǎ   shì
# 194 山长水阔   shān cháng  shuǐ   kuò
# 195 山节藻棁   shān   jié   zǎo    lì
# 196 山林隐逸   shān   lín   yǐn    yì
# 197 山盟海誓   shān  méng   hǎi   shì
# 198 山明水秀   shān  míng  shuǐ   xiù
# 199 山鸣谷应   shān  míng    gǔ  yìng
# 200 山穷水断   shān qióng  shuǐ  duàn
# 201 山穷水尽   shān qióng  shuǐ   jìn
# 202 山容海纳   shān  róng   hǎi    nà
# 203 山肴海错   shān   yáo   hǎi   cuò
# 204 山肴野蔌   shān   yáo    yě    sù
# 205 烧琴煮鹤   shāo   qín   zhǔ    hè
# 206 深仇宿怨   shēn  chóu   xiǔ  yuàn
# 207 深谋远虑   shēn   móu  yuǎn    lǜ
# 208 深谋远略   shēn   móu  yuǎn   lüè
# 209 深图远算   shēn    tú  yuǎn  suàn
# 210 深猷远计   shēn   yóu  yuǎn    jì
# 211 生财有道  shēng   cái   yǒu   dào
# 212 诗肠鼓吹    shī   chá    gǔ  chuì
# 213 诗云子曰    shī   yún    zǐ   yuè
# 214 殊形诡状    shū  xíng   guǐzhuàng
# 215 梳云掠月    shū   yún   lüě   yuè
# 216 思前想后     sī  qián xiǎng   hòu
# 217 斯文扫地     sī   wén   sǎo    dì
# 218 搜岩采干    sōu   yán   cǎi   gàn
# 219 酸甜苦辣   suān  tián    kǔ    là
# 220 酸文假醋   suān   wén   jiǎ    cù
# 221 酸咸苦辣   suān  xián    kǔ    là
# 222 挑肥拣瘦   tiāo   féi  jiǎn  shòu
# 223 挑毛拣刺   tiāo   máo  jiǎn    cì
# 224 通衢广陌   tōng    qú guǎng    mò
# 225 偷闲躲静    tōu  xián   duǒ  jìng
# 226 吞云吐雾    tūn   yún    tǔ    wù
# 227 危言竦论    wēi   yán  sǒng   lùn
# 228 偎红倚翠    wēi  hóng    yǐ   cuì
# 229 希奇古怪     xī    qí    gǔ  guài
# 230 析骸以爨     xī   hái    yǐ  cuàn
# 231 息黥补劓     xī  qíng    bǔ    yì
# 232 稀奇古怪     xī    qí    gǔ  guài
# 233 膝行肘步     xī  xíng  zhǒu    bù
# 234 掀拳裸袖   xiān  quán   luǒ   xiù
# 235 相濡以沫  xiāng    rú    yǐ    mò
# 236 枭蛇鬼怪   xiāo   shé   guǐ  guài
# 237 消愁解闷   xiāo  chóu   jiě   mèn
# 238 逍遥法外   xiāo   yáo    fǎ   wài
# 239 鸮鸣鼠暴  zhāng  míng   shǔ   bào
# 240 心寒胆落    xīn   hán   dǎn   luò
# 241 心寒胆战    xīn   hán   dǎn  zhàn
# 242 心怀叵测    xīn  huái    pǒ    cè
# 243 心怀忐忑    xīn  huái   tǎn    tè
# 244 心明眼亮    xīn  míng   yǎn liàng
# 245 心如槁木    xīn    rú   gǎo    mù
# 246 心直口快    xīn   zhí   kǒu  kuài
# 247 心直嘴快    xīn   zhí   zuǐ  kuài
# 248 星离雨散   xīng    lí    yǔ   sàn
# 249 胸怀磊落  xiōng  huái   lěi   luò
# 250 胸无点墨  xiōng    wú  diǎn    mò
# 251 修桥补路    xiū  qiáo    bǔ    lù
# 252 虚情假意     xū  qíng   jiǎ    yì
# 253 揎拳拢袖   xuān  quán  lǒng   xiù
# 254 揎拳掳袖   xuān  quán    lǔ   xiù
# 255 揎拳裸臂   xuān  quán   luǒ    bì
# 256 揎拳裸袖   xuān  quán   luǒ   xiù
# 257 揎拳捰袖   xuān  quán  lǒng   xiù
# 258 揎拳舞袖   xuān  quán    wǔ   xiù
# 259 妖魔鬼怪    yāo    mó   guǐ  guài
# 260 一劳久逸     yī   láo   jiǔ    yì
# 261 一劳永逸     yī   láo  yǒng    yì
# 262 一硼地     yī   niú   hǒu    dì
# 263 一人有庆     yī   rén   yǒu  qìng
# 264 一无所获     yī    wú   suǒ   huò
# 265 依头缕当     yī   tóu    lǚ  dàng
# 266 因循守旧    yīn   xún  shǒu   jiù
# 267 阴谋诡计    yīn   móu   guǐ    jì
# 268 音容宛在    yīn  róng   wǎn   zài
# 269 英雄本色   yīng xióng   běn    sè
# 270 鹰瞵虎视   yīng   lín    hǔ   shì
# 271 鹰扬虎视   yīng  yáng    hǔ   shì
# 272 鹰扬虎噬   yīng  yáng    hǔ   shì
# 273 雍荣雅步   yōng  róng    yǎ    bù
# 274 雍容雅步   yōng  róng    yǎ    bù
# 275 优柔寡断    yōu   róu   guǎ  duàn
# 276 渊谋远略   yuān   móu  yuǎn   lüè
# 277 渊图远算   yuān    tú  yuǎn  suàn
# 278 渊源有自   yuān  yuán   yǒu    zì
# 279 张眉努目  zhāng   méi    nǔ    mù
# 280 张王李赵  zhāng  wáng    lǐ  zhào
# 281 獐头鼠目  zhāng   tóu   shǔ    mù
# 282 遮前掩后    zhē  qián   yǎn   hòu
# 283 遮人耳目    zhē   rén    ěr    mù
# 284 遮人眼目    zhē   rén   yǎn    mù
# 285 真独简贵   zhēn    dú  jiǎn   guì
# 286 争前恐后  zhēng  qián  kǒng   hòu
# 287 争强显胜  zhēng qiáng  xiǎn shèng
# 288 争权攘利  zhēng  quán  rǎng    lì
# 289 中流底柱  zhōng   liú    dǐ   zhù
# 290 中流砥柱  zhōng   liú    dǐ   zhù
# 291 钟鸣鼎列  zhōng  míng  dǐng   liè
# 292 钟鸣鼎重  zhōng  míng  dǐng zhòng
# 293 朱唇粉面    zhū  chún   fěn  miàn
# 294 朱楼绮户    zhū   lóu    qǐ    hù
# 295 珠零锦粲    zhū  líng   jǐn   càn
# 296 诸如此类    zhū    rú    cǐ   lèi
# 297 诸如此例    zhū    rú    cǐ    lì
# 298 庄严宝相 zhuāng   yán   bǎo xiàng
# 299 遵时养晦    zūn   shí  yǎng   huì

# %%
def filter_shengmuyunmu(data,exclude=[],position_include=[[],[],[],[]],position_exclude=[[],[],[],[]],show=False):
# input para:
#     data: idiom data
#     exclude: the idiom did not contain these shengmu/yunmu 
#     position_include: the shengmu/yunmu at the specific position
#     position_exclude: the idiom contain these shengmu/yunmu but not at this position
    count = 0
    for chengyu in data:
        sm = chengyu['shengmu']
        ym = chengyu['yunmu']
        # check char number, must be 4
        if len(sm) != 4:
            continue
        flag = True
        for i in range(4):
            if (sm[i] in exclude) or (ym[i] in exclude)\
              or (sm[i] in position_exclude[i]) or (ym[i] in position_exclude[i])\
              or (position_include[i] and (position_include[i] not in [sm[i],ym[i]])):
                # print(chengyu['word'],sm[i],ym[i],exclude,position_exclude[i],position_include[i])
                flag = False
                break
        if not flag: continue
        for smym in reduce(lambda x,y: x+y, position_exclude):
            if smym not in sm+ym:
                # print(chengyu['word'],smym,sm+ym)
                flag = False
                break
        if not flag: continue
        count += 1
        if show and count<1000: print('%03d'%count,chengyu['word'],'%6s%6s%6s%6s'%tuple(chengyu['pinyin']))
        yield chengyu
# test
if test:
    result3 = list(filter_shengmuyunmu(result1,exclude=['w','u','g','uang','i','s','e'],position_include=[[],[],[],[]],position_exclude=[[],[],['sh'],[]],show=True))
    result4 = list(filter_shengmuyunmu(result2,exclude=['j','ing','en','m','an','u'],position_include=[[],[],[],[]],position_exclude=[[],['sh'],[],['f']],show=True))
# Out:
# 001 安常履顺     ān cháng    lǚ  shùn
# 002 飞禽走兽    fēi   qín   zǒu  shòu
# 003 风调雨顺   fēng  tiáo    yǔ  shùn
# 004 郊寒岛瘦   jiāo   hán   dǎo  shòu
# 005 精神百倍   jīng  shén   bǎi   bèi
# 006 拘神遣将     jū  shén  qiǎn jiàng
# 007 山容海纳   shān  róng   hǎi    nà
# 008 山肴海错   shān   yáo   hǎi   cuò
# 009 深仇宿怨   shēn  chóu   xiǔ  yuàn
# 010 深谋远虑   shēn   móu  yuǎn    lǜ
# 011 深谋远略   shēn   móu  yuǎn   lüè
# 012 生财有道  shēng   cái   yǒu   dào
# 013 挑肥拣瘦   tiāo   féi  jiǎn  shòu
# 014 争强显胜  zhēng qiáng  xiǎn shèng
# 001 飞禽走兽    fēi   qín   zǒu  shòu
# 002 风调雨顺   fēng  tiáo    yǔ  shùn

# %%
def filter_hanzi(data,hanzi,position=0,show=False):
# input para: only one hanzi is supported
#     data: idiom data
#     hanzi: hanzi
#     position: int, use 1-4 to represent the position of the hanzi, 0 for dont know.
    count = 0
    for chengyu in data:
        if position == 0:
            if hanzi in chengyu['word']:
                count += 1
                if show and count<1000: print('%03d'%count,chengyu['word'],'%6s%6s%6s%6s'%tuple(chengyu['pinyin']))
                yield chengyu
        else:
            if hanzi == chengyu['word'][position-1]:
                count += 1
                if show and count<1000: print('%03d'%count,chengyu['word'],'%6s%6s%6s%6s'%tuple(chengyu['pinyin']))
                yield chengyu
# test
if test:
    result2a = list(filter_hanzi(result1,hanzi='一',show=True))
    result2b = list(filter_hanzi(result1,hanzi='一',position=3,show=True))
# Out:
# 001 人己一视    rén    jǐ    yī   shì
# 002 人手一册    rén  shǒu    yī    cè
# 003 一劳久逸     yī   láo   jiǔ    yì
# 004 一劳永逸     yī   láo  yǒng    yì
# 005 一硼地     yī   niú   hǒu    dì
# 006 一人有庆     yī   rén   yǒu  qìng
# 007 一无所获     yī    wú   suǒ   huò
# 001 人己一视    rén    jǐ    yī   shì
# 002 人手一册    rén  shǒu    yī    cè

# %%
print('***** Solving Handle(Chinese Wordle) *****')
print('notice: must contain all 4 shengdiaos in your first try.')
print('''Input:
shengdiao: a four digital number with "1" "2" "3" "4" represents shengdiao of each char. input grey directly, add "-" before orange, add '+' before green.. Use enter to skip.
shengmu/yunmu: input all the 8 shengmu/yunmu with one space (' ') as the delimiter, input two spaces if a char has no shengmu. input grey directly, add '-' before orange, add '+' before green, tap sapce . Use enter to skip.
hanzi: input an included hanzi and its right position(if has)， with space as the delimeter.

example:
    correct answer: 风调雨顺
    first guess: 五光十色
        shengdiao: -3-1-2+4
        shengmu/yunmu: w u g uang -sh i s e
        hanzi: (enter to skip)
    second guess: 精神满腹
        shengdiao: +1+2+3+4
        shengmu/yunmu: j ing -sh en m an -f u
        hanzi: (enter to skip)
    you will get the filtered chengyu:
        001 飞禽走兽    fēi   qín   zǒu  shòu
        002 风调雨顺   fēng  tiáo    yǔ  shùn
''')
# Out:
# ***** Solving Handle(Chinese Wordle) *****
# notice: must contain all 4 shengdiaos in your first try.
# Input:
# shengdiao: a four digital number with "1" "2" "3" "4" represents shengdiao of each char. input grey directly, add "-" before orange, add '+' before green.. Use enter to skip.
# shengmu/yunmu: input all the 8 shengmu/yunmu with one space (' ') as the delimiter, input two spaces if a char has no shengmu. input grey directly, add '-' before orange, add '+' before green, tap sapce . Use enter to skip.
# hanzi: input an included hanzi and its right position(if has)， with space as the delimeter.
#
# example:
#     correct answer: 风调雨顺
#     first guess: 五光十色
#         shengdiao: -3-1-2+4
#         shengmu/yunmu: w u g uang -sh i s e
#         hanzi: (enter to skip)
#     second guess: 精神满腹
#         shengdiao: +1+2+3+4
#         shengmu/yunmu: j ing -sh en m an -f u
#         hanzi: (enter to skip)
#     you will get the filtered chengyu:
#         001 飞禽走兽    fēi   qín   zǒu  shòu
#         002 风调雨顺   fēng  tiáo    yǔ  shùn

# %%
result = idiom_data
while(True):
    sd_raw = input('shengdiao: ')
    if sd_raw:
        lsd = list(sd_raw)
        lsd.reverse()
        inc = ''
        exc = ''
        while(True):
            try:
                ch = lsd.pop()
            except Exception as e:
                break
            if ch == '+':
                inc += lsd.pop()
                exc += '0'
            elif ch == '-':
                inc += '0'
                exc += lsd.pop()
            else:
                inc += '0'
                exc += '0'
        result = list(filter_shengdiao(result,include=inc,exclude=exc,show=True))

    sy_raw = input('shengmu/yunmu: ')
    if sy_raw:
        lsy = sy_raw.split(' ')
        lsy.reverse()
        exc = []
        pinc = [[],[],[],[]]
        pexc = [[],[],[],[]]
        for i in range(4):
            for j in range(2):
                sy = lsy.pop()
                if sy:
                    if sy[0] == '-':
                        pexc[i] += [sy[1:]]
                    elif sy[0] == '+':
                        pinc[i] += [sy[1:]]
                    else:
                        exc += [sy]
        result = list(filter_shengmuyunmu(result,exclude=exc,position_include=pinc,position_exclude=pexc,show=True))

    hz_raw = input('hanzi: ')
    if hz_raw:
        lhz = hz_raw.split(' ')
        hz = lhz[0]
        if len(lhz) == 2:
            pos = lhz[1]
        else:
            pos = 0
        result = list(filter_hanzi(result,hanzi=hz,position=pos,show=True))
    
    if not (sd_raw or sy_raw or hz_raw):
        break
# Out:
# shengdiao:  -3-1-2+4
# 001 阿其所好      ē    qí   suǒ   hào
# 002 阿谀谄媚      ē    yú  chǎn   mèi
# 003 安常处顺     ān cháng   chǔ  shùn
# 004 安常履顺     ān cháng    lǚ  shùn
# 005 安常守分     ān cháng  shǒu   fèn
# 006 安常守故     ān cháng  shǒu    gù
# 007 安贫守道     ān   pín  shǒu   dào
# 008 安时处顺     ān   shí   chǔ  shùn
# 009 鞍前马后     ān  qián    mǎ   hòu
# 010 昂首天外    áng  shǒu  tiān   wài
# 011 白眼相看    bái   yǎn xiāng   kàn
# 012 白纸黑字    bái   zhǐ   hēi    zì
# 013 邦国殄瘁   bāng   guó  tiǎn   cuì
# 014 膘肥体壮   biāo   féi    tǐzhuàng
# 015 别有风趣    bié   yǒu  fēng    qù
# 016 别有风味    bié   yǒu  fēng   wèi
# 017 别有天地    bié   yǒu  tiān    dì
# 018 别有滋味    bié   yǒu    zī   wèi
# 019 宾朋满座    bīn  péng   mǎn   zuò
# 020 冰魂雪魄   bīng   hún   xuě    pò
# 021 兵强马壮   bīng qiáng    mǎzhuàng
# 022 兵行诡道   bīng  xíng   guǐ   dào
# 023 拨云睹日     bō   yún    dǔ    rì
# 024 才短思涩    cái  duǎn    sī    sè
# 025 餐霞饮瀣    cān   xiá   yǐn   xiè
# 026 餐霞饮液    cān   xiá   yǐn    yè
# 027 苍黄反复   cāng huáng   fǎn    fù
# 028 长久之计  cháng   jiǔ   zhī    jì
# 029 倡条冶叶  chāng  tiáo    yě    yè
# 030 车尘马迹    chē  zhén    mǎ    jì
# 031 车驰马骤    chē   chí    mǎ  zhòu
# 032 车烦马毙    chē   fán    mǎ    bì
# 033 车填马隘    chē  tián    mǎ    ài
# 034 车辙马迹    chē   zhé    mǎ    jì
# 035 撑肠拄肚  chēng cháng   zhǔ    dù
# 036 撑肠拄腹  chēng cháng   zhǔ    fù
# 037 持久之计    chí   jiǔ   zhī    jì
# 038 出词吐气    chū    cí    tǔ    qì
# 039 出何典记    chū    hé  diǎn    jì
# 040 出奇取胜    chū    qí    qǔ shèng
# 041 出言吐气    chū   yán    tǔ    qì
# 042 疮痍满目 chuāng    yí   mǎn    mù
# 043 吹毛索垢   chuī   máo   suǒ   gòu
# 044 吹毛洗垢   chuī   máo    xǐ   gòu
# 045 撺拳拢袖   cuān  quán  lǒng   xiù
# 046 当门抵户   dāng   mén    dǐ    hù
# 047 当行本色   dāng  xíng   běn    sè
# 048 刀头舔蜜    dāo   tóu  tiǎn    mì
# 049 灯红酒绿   dēng  hóng   jiǔ    lǜ
# 050 低吟浅唱     dī   yín  qiǎn chàng
# 051 颠来簸去   diān   lái    bǒ    qù
# 052 颠来倒去   diān   lái   dǎo    qù
# 053 颠鸾倒凤   diān  luán   dǎo  fèng
# 054 彫虫小技   diāo chóng  xiǎo    jì
# 055 貂蝉满座   diāo  chán   mǎn   zuò
# 056 雕虫小技   diāo chóng  xiǎo    jì
# 057 雕虫小事   diāo chóng  xiǎo   shì
# 058 雕虫小艺   diāo chóng  xiǎo    yì
# 059 东床坦腹   dōngchuáng   tǎn    fù
# 060 掇臀捧屁    duō   tún  pěng    pì
# 061 额手称庆      é  shǒu chēng  qìng
# 062 额手称颂      é  shǒu chēng  sòng
# 063 额手相庆      é  shǒu xiāng  qìng
# 064 发凡起例     fā   fán    qǐ    lì
# 065 发蒙解惑     fā  méng   jiě   huò
# 066 发扬蹈厉     fā  yáng   dǎo    lì
# 067 幡然悔悟    fān   rán   huǐ    wù
# 068 翻肠搅肚    fān cháng  jiǎo    dù
# 069 翻黄倒皂    fān huáng   dǎo   zào
# 070 翻然改进    fān   rán   gǎi   jìn
# 071 翻然悔悟    fān   rán   huǐ    wù
# 072 飞刍挽粒    fēi   chú   wǎn    lì
# 073 飞刍挽粟    fēi   chú   wǎn    sù
# 074 飞粮挽秣    fēi liáng   wǎn    mò
# 075 飞禽走兽    fēi   qín   zǒu  shòu
# 076 飞文染翰    fēi   wén   rǎn   hàn
# 077 飞沿走壁    fēi   yán   zǒu    bì
# 078 飞檐走壁    fēi   yán   zǒu    bì
# 079 分朋引类    fēn  péng   yǐn   lèi
# 080 丰年稔岁   fēng  nián   rěn   suì
# 081 风驰雨骤   fēng   chí    yǔ  zhòu
# 082 风调雨顺   fēng  tiáo    yǔ  shùn
# 083 风鬟雨鬓   fēng  huán    yǔ   bìn
# 084 风雷火炮   fēng   léi   huǒ   pào
# 085 风行水上   fēng  xíng  shuǐ shàng
# 086 风行雨散   fēng  xíng    yǔ   sàn
# 087 风烛草露   fēng   zhú   cǎo    lù
# 088 锋芒所向   fēng  máng   suǒ xiàng
# 089 蜂合蚁聚   fēng    hé    yǐ    jù
# 090 蜂屯蚁附   fēng   tún    yǐ    fù
# 091 蜂屯蚁聚   fēng   tún    yǐ    jù
# 092 蜂营蚁队   fēng  yíng    yǐ   duì
# 093 蜂攒蚁聚   fēng  cuán    yǐ    jù
# 094 逢场竿木   féng chǎng   gān    mù
# 095 佛眼相看     fó   yǎn xiāng   kàn
# 096 桴鼓相应     fú    gǔ xiāng  yìng
# 097 干名采誉    gān  míng   cǎi    yù
# 098 纲提领挈   gāng    tí  lǐng   qiè
# 099 高朋满座    gāo  péng   mǎn   zuò
# 100 高情远意    gāo  qíng  yuǎn    yì
# 101 高情远韵    gāo  qíng  yuǎn   yùn
# 102 高情远致    gāo  qíng  yuǎn   zhì
# 103 高人雅士    gāo   rén    yǎ   shì
# 104 高识远见    gāo   shí  yuǎn  jiàn
# 105 高文典册    gāo   wén  diǎn    cè
# 106 高文典策    gāo   wén  diǎn    cè
# 107 膏梁锦绣    gāo liáng   jǐn   xiù
# 108 膏梁子弟    gāo liáng    zǐ    dì
# 109 膏粱锦绣    gāo liáng   jǐn   xiù
# 110 膏粱子弟    gāo liáng    zǐ    dì
# 111 膏腴子弟    gāo    yú    zǐ    dì
# 112 歌楼舞榭     gē   lóu    wǔ   xiè
# 113 歌台舞榭     gē   tái    wǔ   xiè
# 114 歌莺舞燕     gē  yíng    wǔ   yàn
# 115 攻城掠地   gōng chéng   lüě    dì
# 116 攻城野战   gōng chéng    yě  zhàn
# 117 攻瑕索垢   gōng   xiá   suǒ   gòu
# 118 孤雌寡鹤     gū    cí   guǎ    hè
# 119 孤儿寡妇     gū    ér   guǎ    fù
# 120 孤行己见     gū  xíng    jǐ  jiàn
# 121 孤行己意     gū  xíng    jǐ    yì
# 122 孤云野鹤     gū   yún    yě    hè
# 123 瓜田李下    guā  tián    lǐ   xià
# 124 刮肠洗胃    guā cháng    xǐ   wèi
# 125 鳏鱼渴凤   guān    yú    kě  fèng
# 126 光明磊落  guāng  míng   lěi   luò
# 127 光前启后  guāng  qián    qǐ   hòu
# 128 归邪转曜    guī   xié zhuǎn   yào
# 129 龟文鸟迹    guī   wén  niǎo    jì
# 130 规绳矩墨    guī shéng    jǔ    mò
# 131 规贤矩圣    guī  xián    jǔ shèng
# 132 规行矩步    guī  xíng    jǔ    bù
# 133 规言矩步    guī   yán    jǔ    bù
# 134 合眼摸象     hé   yǎn    mō xiàng
# 135 河海清宴     hé   hǎi  qīng   yàn
# 136 呼朋引类     hū  péng   yǐn   lèi
# 137 瑚琏之器     hú  liǎn   zhī    qì
# 138 花红柳绿    huā  hóng   liǔ    lǜ
# 139 花明柳暗    huā  míng   liǔ    àn
# 140 花明柳媚    huā  míng   liǔ   mèi
# 141 花衢柳陌    huā    qú   liǔ    mò
# 142 花团锦簇    huā  tuán   jǐn    cù
# 143 花攒锦簇    huā  cuán   jǐn    cù
# 144 花攒锦聚    huā  cuán   jǐn    jù
# 145 灰容土貌    huī  róng    tǔ   mào
# 146 灰头土面    huī   tóu    tǔ  miàn
# 147 昏头转向    hūn   tóu zhuǎn xiàng
# 148 击搏挽裂     jī    bó   wǎn   liè
# 149 鸡肠狗肚     jī cháng   gǒu    dù
# 150 鸡零狗碎     jī  líng   gǒu   suì
# 151 鸡鸣狗盗     jī  míng   gǒu   dào
# 152 鸡鸣狗吠     jī  míng   gǒu   fèi
# 153 鸡鸣犬吠     jī  míng  quǎn   fèi
# 154 积德累善     jī    dé   lěi  shàn
# 155 积年累岁     jī  nián   lěi   suì
# 156 积年累月     jī  nián   lěi   yuè
# 157 积时累日     jī   shí   lěi    rì
# 158 奸淫掳掠   jiān   yín    lǔ   lüè
# 159 肩从齿序   jiān  cóng   chǐ    xù
# 160 郊寒岛瘦   jiāo   hán   dǎo  shòu
# 161 今愁古恨    jīn  chóu    gǔ   hèn
# 162 金迷纸碎    jīn    mí   zhǐ   suì
# 163 金迷纸醉    jīn    mí   zhǐ   zuì
# 164 矜才使气    jīn   cái   shǐ    qì
# 165 襟怀磊落    jīn  huái   lěi   luò
# 166 襟怀洒落    jīn  huái    sǎ   luò
# 167 经纶满腹   jīng   lún   mǎn    fù
# 168 经年累月   jīng  nián   lěi   yuè
# 169 精诚所至   jīng chéng   suǒ   zhì
# 170 精神百倍   jīng  shén   bǎi   bèi
# 171 精神满腹   jīng  shén   mǎn    fù
# 172 拘挛补衲     jū  luán    bǔ    nà
# 173 拘神遣将     jū  shén  qiǎn jiàng
# 174 磕头礼拜     kē   tóu    lǐ   bài
# 175 坑蒙拐骗   kēng  méng  guǎi  piàn
# 176 宽洪海量   kuān  hóng   hǎi liàng
# 177 来者居上    lái   zhě    jū shàng
# 178 兰芷之室    lán   zhǐ   zhī   shì
# 179 离本徼末     lí   běn   yāo    mò
# 180 离本趣末     lí   běn    qū    mò
# 181 离本依末     lí   běn    yī    mò
# 182 连理之木   lián    lǐ   zhī    mù
# 183 门闾之望    mén    lǚ   zhī  wàng
# 184 名满天下   míng   mǎn  tiān   xià
# 185 牛口之下    niú   kǒu   zhī   xià
# 186 喷云吐雾    pēn   yún    tǔ    wù
# 187 烹龙煮凤   pēng  lóng   zhǔ  fèng
# 188 批鳞请剑     pī   lín  qǐng  jiàn
# 189 皮里抽肉     pí    lǐ  chōu   ròu
# 190 凭几之诏   píng    jǐ   zhī  zhào
# 191 蒲柳之质     pú   liǔ   zhī   zhì
# 192 妻离子散     qī    lí    zǐ   sàn
# 193 妻梅子鹤     qī   mén    zǐ    hè
# 194 千锤百炼   qiān  chuí   bǎi  liàn
# 195 千伶百俐   qiān  líng   bǎi    lì
# 196 千奇百怪   qiān    qí   bǎi  guài
# 197 千随百顺   qiān   suí   bǎi  shùn
# 198 搴旗取将   qiān    qí    qǔ jiàng
# 199 搴旗斩将   qiān    qí  zhǎn jiàng
# 200 强弩之末  qiáng    nǔ   zhī    mò
# 201 亲如骨肉    qīn    rú    gǔ   ròu
# 202 亲贤远佞    qīn  xián  yuǎn  nìng
# 203 嵚崎磊落    qīn    qí   lěi   luò
# 204 青裙缟袂   qīng   qún   gǎo   mèi
# 205 青堂瓦舍   qīng  táng    wǎ   shè
# 206 青蝇点璧   qīng  yíng  diǎn    bì
# 207 青蝇点素   qīng  yíng  diǎn    sù
# 208 青蝇点玉   qīng  yíng  diǎn    yù
# 209 轻财好士   qīng   cái   hǎo   shì
# 210 轻裘缓带   qīng   qiú  huǎn   dài
# 211 轻裘缓辔   qīng   qiú  huǎn   pèi
# 212 轻言寡信   qīng   yán   guǎ   xìn
# 213 裘马声色    qiú    mǎ shēng    sè
# 214 屈节辱命     qū   jié    rǔ  mìng
# 215 饶有风趣    ráo   yǒu  fēng    qù
# 216 人己一视    rén    jǐ    yī   shì
# 217 人手一册    rén  shǒu    yī    cè
# 218 戎马劻勷   róng    mǎ   dān  xiào
# 219 如虎生翼     rú    hǔ shēng    yì
# 220 如虎添翼     rú    hǔ  tiān    yì
# 221 三朝五日    sān  cháo    wǔ    rì
# 222 三环五扣    sān  huán    wǔ   kòu
# 223 三皇五帝    sān huáng    wǔ    dì
# 224 三回五次    sān   huí    wǔ    cì
# 225 三节两寿    sān   jié liǎng  shòu
# 226 三年五载    sān  nián    wǔ   zài
# 227 三头两面    sān   tóu liǎng  miàn
# 228 三头两日    sān   tóu liǎng    rì
# 229 三头两绪    sān   tóu liǎng    xù
# 230 三言两句    sān   yán liǎng    jù
# 231 三足鼎立    sān    zú  dǐng    lì
# 232 骚人雅士    sāo   rén    yǎ   shì
# 233 山长水阔   shān cháng  shuǐ   kuò
# 234 山节藻棁   shān   jié   zǎo    lì
# 235 山林隐逸   shān   lín   yǐn    yì
# 236 山盟海誓   shān  méng   hǎi   shì
# 237 山明水秀   shān  míng  shuǐ   xiù
# 238 山鸣谷应   shān  míng    gǔ  yìng
# 239 山穷水断   shān qióng  shuǐ  duàn
# 240 山穷水尽   shān qióng  shuǐ   jìn
# 241 山容海纳   shān  róng   hǎi    nà
# 242 山肴海错   shān   yáo   hǎi   cuò
# 243 山肴野蔌   shān   yáo    yě    sù
# 244 烧琴煮鹤   shāo   qín   zhǔ    hè
# 245 深仇宿怨   shēn  chóu   xiǔ  yuàn
# 246 深谋远虑   shēn   móu  yuǎn    lǜ
# 247 深谋远略   shēn   móu  yuǎn   lüè
# 248 深图远算   shēn    tú  yuǎn  suàn
# 249 深猷远计   shēn   yóu  yuǎn    jì
# 250 神竦心惕   shén  sǒng   xīn    tì
# 251 生财有道  shēng   cái   yǒu   dào
# 252 诗肠鼓吹    shī   chá    gǔ  chuì
# 253 诗云子曰    shī   yún    zǐ   yuè
# 254 殊形诡状    shū  xíng   guǐzhuàng
# 255 梳云掠月    shū   yún   lüě   yuè
# 256 思前想后     sī  qián xiǎng   hòu
# 257 斯文扫地     sī   wén   sǎo    dì
# 258 搜岩采干    sōu   yán   cǎi   gàn
# 259 酸甜苦辣   suān  tián    kǔ    là
# 260 酸文假醋   suān   wén   jiǎ    cù
# 261 酸咸苦辣   suān  xián    kǔ    là
# 262 桃李之教    táo    lǐ   zhī  jiào
# 263 桃李之馈    táo    lǐ   zhī   kuì
# 264 挑肥拣瘦   tiāo   féi  jiǎn  shòu
# 265 挑毛拣刺   tiāo   máo  jiǎn    cì
# 266 通衢广陌   tōng    qú guǎng    mò
# 267 同美相妒   tóng   měi xiāng    dù
# 268 偷闲躲静    tōu  xián   duǒ  jìng
# 269 投鼠之忌    tóu   shǔ   zhī    jì
# 270 吞云吐雾    tūn   yún    tǔ    wù
# 271 危言竦论    wēi   yán  sǒng   lùn
# 272 偎红倚翠    wēi  hóng    yǐ   cuì
# 273 文武兼备    wén    wǔ  jiān   bèi
# 274 文武之道    wén    wǔ   zhī   dào
# 275 无可非议     wú    kě   fēi    yì
# 276 无可争辩     wú    kě zhēng  biàn
# 277 梧鼠之技     wú   shǔ   zhī    jì
# 278 希奇古怪     xī    qí    gǔ  guài
# 279 析骸以爨     xī   hái    yǐ  cuàn
# 280 息黥补劓     xī  qíng    bǔ    yì
# 281 稀奇古怪     xī    qí    gǔ  guài
# 282 膝行肘步     xī  xíng  zhǒu    bù
# 283 席卷天下     xí  juǎn  tiān   xià
# 284 席履丰厚     xí    lǚ  fēng   hòu
# 285 掀拳裸袖   xiān  quán   luǒ   xiù
# 286 相濡以沫  xiāng    rú    yǐ    mò
# 287 枭蛇鬼怪   xiāo   shé   guǐ  guài
# 288 消愁解闷   xiāo  chóu   jiě   mèn
# 289 逍遥法外   xiāo   yáo    fǎ   wài
# 290 鸮鸣鼠暴  zhāng  míng   shǔ   bào
# 291 心寒胆落    xīn   hán   dǎn   luò
# 292 心寒胆战    xīn   hán   dǎn  zhàn
# 293 心怀叵测    xīn  huái    pǒ    cè
# 294 心怀忐忑    xīn  huái   tǎn    tè
# 295 心明眼亮    xīn  míng   yǎn liàng
# 296 心如槁木    xīn    rú   gǎo    mù
# 297 心直口快    xīn   zhí   kǒu  kuài
# 298 心直嘴快    xīn   zhí   zuǐ  kuài
# 299 星离雨散   xīng    lí    yǔ   sàn
# 300 形影相吊   xíng  yǐng xiāng  diào
# 301 形影相对   xíng  yǐng xiāng   duì
# 302 形影相附   xíng  yǐng xiāng    fù
# 303 胸怀磊落  xiōng  huái   lěi   luò
# 304 胸无点墨  xiōng    wú  diǎn    mò
# 305 修桥补路    xiū  qiáo    bǔ    lù
# 306 虚情假意     xū  qíng   jiǎ    yì
# 307 揎拳拢袖   xuān  quán  lǒng   xiù
# 308 揎拳掳袖   xuān  quán    lǔ   xiù
# 309 揎拳裸臂   xuān  quán   luǒ    bì
# 310 揎拳裸袖   xuān  quán   luǒ   xiù
# 311 揎拳捰袖   xuān  quán  lǒng   xiù
# 312 揎拳舞袖   xuān  quán    wǔ   xiù
# 313 玄圃积玉   xuán    pǔ    jī    yù
# 314 妖魔鬼怪    yāo    mó   guǐ  guài
# 315 一劳久逸     yī   láo   jiǔ    yì
# 316 一劳永逸     yī   láo  yǒng    yì
# 317 一硼地     yī   niú   hǒu    dì
# 318 一人有庆     yī   rén   yǒu  qìng
# 319 一无所获     yī    wú   suǒ   huò
# 320 依头缕当     yī   tóu    lǚ  dàng
# 321 因循守旧    yīn   xún  shǒu   jiù
# 322 阴谋诡计    yīn   móu   guǐ    jì
# 323 音容宛在    yīn  róng   wǎn   zài
# 324 英雄本色   yīng xióng   běn    sè
# 325 鹰瞵虎视   yīng   lín    hǔ   shì
# 326 鹰扬虎视   yīng  yáng    hǔ   shì
# 327 鹰扬虎噬   yīng  yáng    hǔ   shì
# 328 盈满之咎   yíng   mǎn   zhī   jiù
# 329 雍荣雅步   yōng  róng    yǎ    bù
# 330 雍容雅步   yōng  róng    yǎ    bù
# 331 优柔寡断    yōu   róu   guǎ  duàn
# 332 鱼米之地     yú    mǐ   zhī    dì
# 333 渊谋远略   yuān   móu  yuǎn   lüè
# 334 渊图远算   yuān    tú  yuǎn  suàn
# 335 渊源有自   yuān  yuán   yǒu    zì
# 336 圆孔方木   yuán  kǒng  fāng    mù
# 337 张眉努目  zhāng   méi    nǔ    mù
# 338 张王李赵  zhāng  wáng    lǐ  zhào
# 339 獐头鼠目  zhāng   tóu   shǔ    mù
# 340 遮前掩后    zhē  qián   yǎn   hòu
# 341 遮人耳目    zhē   rén    ěr    mù
# 342 遮人眼目    zhē   rén   yǎn    mù
# 343 真独简贵   zhēn    dú  jiǎn   guì
# 344 争前恐后  zhēng  qián  kǒng   hòu
# 345 争强显胜  zhēng qiáng  xiǎn shèng
# 346 争权攘利  zhēng  quán  rǎng    lì
# 347 中流底柱  zhōng   liú    dǐ   zhù
# 348 中流砥柱  zhōng   liú    dǐ   zhù
# 349 钟鸣鼎列  zhōng  míng  dǐng   liè
# 350 钟鸣鼎重  zhōng  míng  dǐng zhòng
# 351 重睹天日  chóng    dǔ  tiān    rì
# 352 朱唇粉面    zhū  chún   fěn  miàn
# 353 朱楼绮户    zhū   lóu    qǐ    hù
# 354 珠零锦粲    zhū  líng   jǐn   càn
# 355 诸如此类    zhū    rú    cǐ   lèi
# 356 诸如此例    zhū    rú    cǐ    lì
# 357 庄严宝相 zhuāng   yán   bǎo xiàng
# 358 遵时养晦    zūn   shí  yǎng   huì
# shengmu/yunmu:  w u g uang -sh i s e
# 001 安常履顺     ān cháng    lǚ  shùn
# 002 飞禽走兽    fēi   qín   zǒu  shòu
# 003 风调雨顺   fēng  tiáo    yǔ  shùn
# 004 郊寒岛瘦   jiāo   hán   dǎo  shòu
# 005 精神百倍   jīng  shén   bǎi   bèi
# 006 拘神遣将     jū  shén  qiǎn jiàng
# 007 山容海纳   shān  róng   hǎi    nà
# 008 山肴海错   shān   yáo   hǎi   cuò
# 009 深仇宿怨   shēn  chóu   xiǔ  yuàn
# 010 深谋远虑   shēn   móu  yuǎn    lǜ
# 011 深谋远略   shēn   móu  yuǎn   lüè
# 012 生财有道  shēng   cái   yǒu   dào
# 013 挑肥拣瘦   tiāo   féi  jiǎn  shòu
# 014 争强显胜  zhēng qiáng  xiǎn shèng
# hanzi:
# shengdiao:  +1+2+3+4
# 001 安常履顺     ān cháng    lǚ  shùn
# 002 飞禽走兽    fēi   qín   zǒu  shòu
# 003 风调雨顺   fēng  tiáo    yǔ  shùn
# 004 郊寒岛瘦   jiāo   hán   dǎo  shòu
# 005 精神百倍   jīng  shén   bǎi   bèi
# 006 拘神遣将     jū  shén  qiǎn jiàng
# 007 山容海纳   shān  róng   hǎi    nà
# 008 山肴海错   shān   yáo   hǎi   cuò
# 009 深仇宿怨   shēn  chóu   xiǔ  yuàn
# 010 深谋远虑   shēn   móu  yuǎn    lǜ
# 011 深谋远略   shēn   móu  yuǎn   lüè
# 012 生财有道  shēng   cái   yǒu   dào
# 013 挑肥拣瘦   tiāo   féi  jiǎn  shòu
# 014 争强显胜  zhēng qiáng  xiǎn shèng
# shengmu/yunmu:  j ing -sh en m an -f u
# 001 飞禽走兽    fēi   qín   zǒu  shòu
# 002 风调雨顺   fēng  tiáo    yǔ  shùn
# hanzi:
# shengdiao:
# shengmu/yunmu:
# hanzi:
